# %% [markdown]
# # Niamey download

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
from tqdm.auto import tqdm

from src.datasources import glofas

# %%
lon_guess, lat_guess = 2.075, 13.525
year = 2022

# %%
glofas.download_reanalysis_year(
    lon=lon_guess,
    lat=lat_guess,
    year=year,
    pitch=0.5,
    clobber=True,
    centered=True,
)
# Out:
# 2025-09-03 15:09:18,522 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03 15:09:19,016 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-03 15:09:19,018 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 15:09:19,019 INFO Request ID is 9f2dae3c-2b1b-4f03-9765-d382e9476611
# INFO:ecmwf.datastores.legacy_client:Request ID is 9f2dae3c-2b1b-4f03-9765-d382e9476611
# 2025-09-03 15:09:19,305 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-03 15:09:28,691 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-03 15:13:41,094 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# a47d297554523baa825109fc6daad449.grib:   0%|          | 0.00/216k [00:00<?, ?B/s]
# PosixPath('temp/pa-aa-ner-flooding/raw/glofas/reanalysis/glofas_raw_reanalysis_lat13.525_lon2.075_2022.grib')

# %%
da_guess = glofas.load_reanalysis_year(
    data_type="raw", lon=lon_guess, lat=lat_guess, year=2022
)

# %%
da_guess.mean(dim="time")["dis24"].plot()

# %%
da_guess.mean(dim="time")["dis24"].plot(vmin=0, vmax=1)

# %%
da_guess.sel(latitude=slice(13.55, 13.45), longitude=slice(2.0, 2.15)).mean(
    dim="time"
)["dis24"].plot(vmin=0, vmax=1)

# %%
da_guess.sel(latitude=slice(13.55, 13.45), longitude=slice(2.0, 2.15)).mean(
    dim="time"
)["dis24"]
# Out:
# <xarray.DataArray 'dis24' (latitude: 2, longitude: 3)> Size: 24B
# array([[2.0381293e+03, 2.0381459e+03, 1.3874143e-01],
#        [3.1250000e-02, 1.7401541e-02, 2.0382100e+03]], dtype=float32)
# Coordinates:
#     step       timedelta64[ns] 8B 1 days
#     surface    float64 8B 0.0
#   * latitude   (latitude) float64 16B 13.52 13.47
#   * longitude  (longitude) float64 24B 2.025 2.075 2.125

# %%
lon, lat = 2.075, 13.52

# %%
glofas.download_reanalysis_year(
    lon=lon,
    lat=lat,
    year=year,
)
# Out:
# 2025-09-03 15:20:12,749 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03 15:20:13,307 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-03 15:20:13,308 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 15:20:13,310 INFO Request ID is 18220062-887e-48ff-a0ea-f10a6f772e3c
# INFO:ecmwf.datastores.legacy_client:Request ID is 18220062-887e-48ff-a0ea-f10a6f772e3c
# 2025-09-03 15:20:13,562 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-03 15:20:22,708 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-03 15:20:35,846 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-03 15:20:47,488 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-03 15:24:34,813 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# fb7c43b7864dfade5eae51474516a911.grib:   0%|          | 0.00/87.0k [00:00<?, ?B/s]
# PosixPath('temp/pa-aa-ner-flooding/raw/glofas/reanalysis/glofas_raw_reanalysis_lat13.52_lon2.075_2022.grib')

# %%
da_better_guess = glofas.load_reanalysis_year(
    data_type="raw", lon=lon, lat=lat, year=2022
)

# %%
da_better_guess.mean(dim="time")
# Out:
# <xarray.Dataset> Size: 36B
# Dimensions:    (latitude: 1, longitude: 1)
# Coordinates:
#     step       timedelta64[ns] 8B 1 days
#     surface    float64 8B 0.0
#   * latitude   (latitude) float64 8B 13.53
#   * longitude  (longitude) float64 8B 2.075
# Data variables:
#     dis24      (latitude, longitude) float32 4B 2.038e+03

# %%
station_name = "niamey"

# %%
for year in tqdm(range(1979, 2025)):
    glofas.download_reanalysis_year(year=year, station_name=station_name)
# Out:
#   0%|          | 0/46 [00:00<?, ?it/s]
# 2025-09-03 15:26:05,064 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03 15:26:05,601 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-03 15:26:05,603 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 15:26:05,606 INFO Request ID is 83bba887-6389-4237-8020-523fb312eb3f
# INFO:ecmwf.datastores.legacy_client:Request ID is 83bba887-6389-4237-8020-523fb312eb3f
# 2025-09-03 15:26:05,832 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-03 15:26:20,200 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-03 15:30:27,747 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# 9eee848b3ff4e5356ac42753e32f319c.grib:   0%|          | 0.00/87.0k [00:00<?, ?B/s]
# 2025-09-03 15:30:31,223 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03 15:30:31,689 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-03 15:30:31,691 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 15:30:31,695 INFO Request ID is 45dcf869-d8ec-420d-a198-ca8a3a6d03ff
# INFO:ecmwf.datastores.legacy_client:Request ID is 45dcf869-d8ec-420d-a198-ca8a3a6d03ff
# 2025-09-03 15:30:31,903 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-03 15:30:40,889 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-03 15:36:53,603 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# a2cd7fc861be13ed1eb10fb8b61edb8a.grib:   0%|          | 0.00/87.2k [00:00<?, ?B/s]
# 2025-09-03 15:36:57,381 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03 15:36:57,854 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-03 15:36:57,855 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 15:36:57,856 INFO Request ID is 452a3656-d6fd-4597-8bc3-bb7b74d5adfa
# INFO:ecmwf.datastores.legacy_client:Request ID is 452a3656-d6fd-4597-8bc3-bb7b74d5adfa
# 2025-09-03 15:36:58,058 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-03 15:37:07,189 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-03 15:41:19,608 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# eee85fff2de890c254d8a3db364c14.grib:   0%|          | 0.00/87.0k [00:00<?, ?B/s]
# 2025-09-03 15:41:22,999 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03 15:41:23,450 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-03 15:41:23,453 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 15:41:23,455 INFO Request ID is e1a7b392-fdd8-4b47-a025-c0a8651b1811
# INFO:ecmwf.datastores.legacy_client:Request ID is e1a7b392-fdd8-4b47-a025-c0a8651b1811
# 2025-09-03 15:41:24,441 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-03 15:41:30,329 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-03 15:45:45,954 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# 54812b2a2e21c7d7235a3f3fcf8fd0b2.grib:   0%|          | 0.00/87.0k [00:00<?, ?B/s]
# 2025-09-03 15:45:49,408 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03 15:45:49,912 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-03 15:45:49,914 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 15:45:49,916 INFO Request ID is ad017fd6-2c73-4d74-a6c1-08c7da884d8c
# INFO:ecmwf.datastores.legacy_client:Request ID is ad017fd6-2c73-4d74-a6c1-08c7da884d8c
# 2025-09-03 15:45:50,895 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-03 15:45:57,570 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-03 15:50:14,691 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# a4b6e527f742ef71b0c65c426f8baa20.grib:   0%|          | 0.00/87.0k [00:00<?, ?B/s]
# 2025-09-03 15:50:18,302 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03 15:50:18,840 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-03 15:50:18,842 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 15:50:18,844 INFO Request ID is e7b3a500-3b93-4726-b863-159c54c985e2
# INFO:ecmwf.datastores.legacy_client:Request ID is e7b3a500-3b93-4726-b863-159c54c985e2
# 2025-09-03 15:50:19,066 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-03 15:50:24,787 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-03 15:54:41,064 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# 67506b83a9843127608a55e8569af9e1.grib:   0%|          | 0.00/87.2k [00:00<?, ?B/s]
# 2025-09-03 15:54:44,798 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03
INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 16:59:25,725 INFO Request ID is 3ad51903-3cc1-4f48-a5d6-342d0855314a
# INFO:ecmwf.datastores.legacy_client:Request ID is 3ad51903-3cc1-4f48-a5d6-342d0855314a
# 2025-09-03 16:59:25,996 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-03 16:59:40,494 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# WARNING:multiurl.http:Recovering from connection error [('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))], attempt 1 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# WARNING:multiurl.http:Recovering from connection error [HTTPSConnectionPool(host='ewds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/3ad51903-3cc1-4f48-a5d6-342d0855314a?log=True&request=True (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x322a97d10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))], attempt 2 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# 2025-09-03 21:38:19,309 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# d8ae88c070ee791b99afdc45e9fa3185.grib:   0%|          | 0.00/87.0k [00:00<?, ?B/s]
# 2025-09-03 21:38:23,502 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03 21:38:24,104 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-03 21:38:24,106 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 21:38:24,107 INFO Request ID is f26c90bf-f604-4215-a7e8-b3672e7c0bff
# INFO:ecmwf.datastores.legacy_client:Request ID is f26c90bf-f604-4215-a7e8-b3672e7c0bff
# 2025-09-03 21:38:24,442 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# WARNING:multiurl.http:Recovering from connection error [HTTPSConnectionPool(host='ewds.climate.copernicus.eu', port=443): Read timed out. (read timeout=60)], attempt 1 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# 2025-09-03 22:06:33,767 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# e37597d5890b9480f2f2ccfdfffc0ede.grib:   0%|          | 0.00/87.2k [00:00<?, ?B/s]
# 2025-09-03 22:06:37,172 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03 22:06:37,662 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-03 22:06:37,665 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 22:06:37,667 INFO Request ID is ee24903c-1877-4b83-a355-3470e52f59f3
# INFO:ecmwf.datastores.legacy_client:Request ID is ee24903c-1877-4b83-a355-3470e52f59f3
# 2025-09-03 22:06:37,858 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-03 22:07:11,528 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-03 22:10:58,821 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# f387a34401eaef30a8b51d5ad2fa20dc.grib:   0%|          | 0.00/87.0k [00:00<?, ?B/s]
# 2025-09-03 22:11:02,363 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03 22:11:02,809 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-03 22:11:02,812 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 22:11:02,815 INFO Request ID is 0912f5c8-661a-4851-bb09-b005e7da16bc
# INFO:ecmwf.datastores.legacy_client:Request ID is 0912f5c8-661a-4851-bb09-b005e7da16bc
# 2025-09-03 22:11:03,008 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-03 22:11:08,694 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-03 22:19:24,616 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# 7ec3fecccf9464c8979a0dee0d1ff9f3.grib:   0%|          | 0.00/87.0k [00:00<?, ?B/s]
# 2025-09-03 22:19:29,306 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03 22:19:29,992 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-03 22:19:29,994 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 22:19:29,996 INFO Request ID is fb1d7987-7485-4b8a-b9dc-67b74789609a
# INFO:ecmwf.datastores.legacy_client:Request ID is fb1d7987-7485-4b8a-b9dc-67b74789609a
# 2025-09-03 22:19:30,311 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-03 22:19:39,517 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# WARNING:multiurl.http:Recovering from connection error [HTTPSConnectionPool(host='ewds.climate.copernicus.eu', port=443): Read timed out. (read timeout=60)], attempt 1 of 500
# WARNING:multiurl.http:Retrying in 120 seconds
# 2025-09-03 22:38:27,202 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# 1e555899637f70e6df99b57488696d46.grib:   0%|          | 0.00/87.0k [00:00<?, ?B/s]
# 2025-09-03 22:38:30,599 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-03 22:38:31,026 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-03 22:38:31,029 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-03 22:38:31,031 INFO Request ID is e092871d-0249-4afc-8bca-4b8d17a53b3d
# INFO:ecmwf.datastores.legacy_client:Request ID is e092871d-0249-4afc-8bca-4b8d17a53b3d
# 2025-09-03 22:38:31,249 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09
INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-04 04:15:04,918 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-04 04:15:04,920 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-04 04:15:04,921 INFO Request ID is d3e4b936-ef96-4908-aad4-aa34034e81d9
# INFO:ecmwf.datastores.legacy_client:Request ID is d3e4b936-ef96-4908-aad4-aa34034e81d9
# 2025-09-04 04:15:05,147 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-04 04:15:19,429 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-04 04:19:26,331 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# 49a1c4a69725a80f29fb5926bea317b4.grib:   0%|          | 0.00/87.0k [00:00<?, ?B/s]
# 2025-09-04 04:19:29,655 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-04 04:19:30,271 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-04 04:19:30,274 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-04 04:19:30,276 INFO Request ID is 992b0f89-b744-474d-954e-d787574ab3c9
# INFO:ecmwf.datastores.legacy_client:Request ID is 992b0f89-b744-474d-954e-d787574ab3c9
# 2025-09-04 04:19:30,480 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-04 04:19:45,029 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# fb7c43b7864dfade5eae51474516a911.grib:   0%|          | 0.00/87.0k [00:00<?, ?B/s]
# 2025-09-04 04:19:48,344 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-04 04:19:48,876 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-04 04:19:48,878 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-04 04:19:48,879 INFO Request ID is 05915825-8d7b-4b3c-84be-909c6074152e
# INFO:ecmwf.datastores.legacy_client:Request ID is 05915825-8d7b-4b3c-84be-909c6074152e
# 2025-09-04 04:19:49,160 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-04 04:20:03,377 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-04 04:24:10,358 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# d9455e502f00f2d8b4b1b0056753f35e.grib:   0%|          | 0.00/87.0k [00:00<?, ?B/s]
# 2025-09-04 04:24:13,817 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-04 04:24:14,470 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-04 04:24:14,471 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-04 04:24:14,472 INFO Request ID is 16baf1d6-dc86-4fb4-b689-c2abd1555594
# INFO:ecmwf.datastores.legacy_client:Request ID is 16baf1d6-dc86-4fb4-b689-c2abd1555594
# 2025-09-04 04:24:14,772 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-04 04:25:31,906 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-09-04 04:30:36,884 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# 9e7f685033a16bfce6c8fb944844b657.grib:   0%|          | 0.00/87.2k [00:00<?, ?B/s]

# %%
glofas.download_reanalysis_year(year=2025, station_name=station_name)
# Out:
# 2025-09-17 14:46:35,471 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# INFO:ecmwf.datastores.legacy_client:[2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-17 14:46:35,825 INFO [2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note that accessing this dataset via CDS for time-critical operation is not advised or supported
# 2025-09-17 14:46:35,826 INFO [2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# INFO:ecmwf.datastores.legacy_client:[2024-02-01T00:00:00] Please note we suggest checking the list of known issues on the GloFAS wiki
# [here](https://confluence.ecmwf.int/display/CEMS/GloFAS+-+Known+Issues)
# before downloading the dataset.
# 2025-09-17 14:46:35,828 INFO Request ID is e47080d0-5e49-4728-853c-5bf6858275f3
# INFO:ecmwf.datastores.legacy_client:Request ID is e47080d0-5e49-4728-853c-5bf6858275f3
# 2025-09-17 14:46:35,984 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-09-17 14:48:31,514 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# 6d2d01e452edd28f29110712e293b86b.grib:   0%|          | 0.00/43.1k [00:00<?, ?B/s]
# PosixPath('temp/pa-aa-ner-flooding/raw/glofas/reanalysis/glofas_raw_reanalysis_niamey_2025.grib')

# %%
glofas.process_reanalysis(station_name)
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]
